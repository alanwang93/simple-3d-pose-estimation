# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
from os import listdir
from os.path import isfile, join

# %%
preds = h5py.File('preds/mytest.h5')['preds']

# %%
preds
# Out:
# <HDF5 dataset "preds": shape (578, 16, 2), type "<f8">

# %%
img_file = open('annot/my_test_images.txt', 'w')
path = 'images/mytest'
filenames = [f for f in listdir(path) if isfile(join(path, f))]
n = len(filenames)

# %%
for i in range(min(preds.shape[0], 10)):
    im = plt.imread(join(path, filenames[i]))
    plt.imshow(im)
    plt.scatter(preds[i][:,0], preds[i][:,1])
    plt.show()
